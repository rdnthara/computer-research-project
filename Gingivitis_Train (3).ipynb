# %% [markdown]
# # InceptionResNetV2 Model Traning

# %% [markdown]
# ## Importing Libraries and Setting Up Environments.

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# %cp -av /content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset Trainable_Dataset
# Out:
# /content
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset' -> 'Trainable_Dataset'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation' -> 'Trainable_Dataset/validation'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe' -> 'Trainable_Dataset/validation/severe'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (454).jpg' -> 'Trainable_Dataset/validation/severe/severe (454).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (174).jpg' -> 'Trainable_Dataset/validation/severe/severe (174).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (245).jpg' -> 'Trainable_Dataset/validation/severe/severe (245).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (215).jpg' -> 'Trainable_Dataset/validation/severe/severe (215).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (344).jpg' -> 'Trainable_Dataset/validation/severe/severe (344).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (235).jpg' -> 'Trainable_Dataset/validation/severe/severe (235).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (410).jpg' -> 'Trainable_Dataset/validation/severe/severe (410).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (216).jpg' -> 'Trainable_Dataset/validation/severe/severe (216).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (393).jpg' -> 'Trainable_Dataset/validation/severe/severe (393).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (461).jpg' -> 'Trainable_Dataset/validation/severe/severe (461).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (406).jpg' -> 'Trainable_Dataset/validation/severe/severe (406).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (465).jpg' -> 'Trainable_Dataset/validation/severe/severe (465).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (325).jpg' -> 'Trainable_Dataset/validation/severe/severe (325).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (269).jpg' -> 'Trainable_Dataset/validation/severe/severe (269).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (494).jpg' -> 'Trainable_Dataset/validation/severe/severe (494).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (489).jpg' -> 'Trainable_Dataset/validation/severe/severe (489).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (413).jpg' -> 'Trainable_Dataset/validation/severe/severe (413).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (367).jpg' -> 'Trainable_Dataset/validation/severe/severe (367).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (334).jpg' -> 'Trainable_Dataset/validation/severe/severe (334).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (182).jpg' -> 'Trainable_Dataset/validation/severe/severe (182).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (260).jpg' -> 'Trainable_Dataset/validation/severe/severe (260).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (178).jpg' -> 'Trainable_Dataset/validation/severe/severe (178).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (232).jpg' -> 'Trainable_Dataset/validation/severe/severe (232).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (331).jpg' -> 'Trainable_Dataset/validation/severe/severe (331).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (284).jpg' -> 'Trainable_Dataset/validation/severe/severe (284).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (249).jpg' -> 'Trainable_Dataset/validation/severe/severe (249).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (402).jpg' -> 'Trainable_Dataset/validation/severe/severe (402).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (265).jpg' -> 'Trainable_Dataset/validation/severe/severe (265).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (309).jpg' -> 'Trainable_Dataset/validation/severe/severe (309).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (396).jpg' -> 'Trainable_Dataset/validation/severe/severe (396).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (200).jpg' -> 'Trainable_Dataset/validation/severe/severe (200).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (239).jpg' -> 'Trainable_Dataset/validation/severe/severe (239).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (229).jpg' -> 'Trainable_Dataset/validation/severe/severe (229).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (452).jpg' -> 'Trainable_Dataset/validation/severe/severe (452).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/severe/severe (498).jpg' -> 'Trainable_Dataset/validation/severe/severe (498).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy' -> 'Trainable_Dataset/validation/healthy'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1175).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1175).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1601).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1601).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1222).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1222).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1108).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1108).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1380).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1380).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1330).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1330).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1185).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1185).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (932).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (932).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1383).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1383).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1357).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1357).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1605).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1605).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1491).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1491).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1142).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1142).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1613).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1613).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (996).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (996).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (947).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (947).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (959).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (959).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (993).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (993).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1699).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1699).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1208).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1208).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (962).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (962).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1262).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1262).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1596).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1596).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1443).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1443).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1174).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1174).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1324).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1324).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1341).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1341).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1599).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1599).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (900).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (900).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1418).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1418).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1617).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1617).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1462).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1462).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1595).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1595).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1435).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1435).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (974).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (974).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1382).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1382).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1619).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1619).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1234).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1234).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1243).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1243).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1514).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1514).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1486).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1486).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1321).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1321).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (883).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (883).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1359).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1359).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1585).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1585).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1389).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1389).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1110).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1110).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1548).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1548).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1529).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1529).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1536).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1536).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1573).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1573).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1237).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1237).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (872).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (872).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1044).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1044).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1621).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1621).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1369).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1369).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1535).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1535).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1688).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1688).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1370).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1370).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1538).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1538).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (886).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (886).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1568).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1568).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1406).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1406).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1305).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1305).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1068).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1068).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1271).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1271).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (854).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (854).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1697).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1697).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1445).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1445).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (926).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (926).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1533).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1533).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1444).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1444).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1143).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1143).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1129).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1129).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1289).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1289).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1479).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1479).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1463).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1463).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1012).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1012).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1275).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1275).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1659).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1659).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1427).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1427).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (931).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (931).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1307).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1307).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1313).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1313).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1569).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1569).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/healthy/healthy (1517).jpg' -> 'Trainable_Dataset/validation/healthy/healthy (1517).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild' -> 'Trainable_Dataset/validation/mild'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (724).jpg' -> 'Trainable_Dataset/validation/mild/mild (724).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (442).jpg' -> 'Trainable_Dataset/validation/mild/mild (442).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (561).jpg' -> 'Trainable_Dataset/validation/mild/mild (561).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (807).jpg' -> 'Trainable_Dataset/validation/mild/mild (807).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (460).jpg' -> 'Trainable_Dataset/validation/mild/mild (460).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (792).jpg' -> 'Trainable_Dataset/validation/mild/mild (792).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (624).jpg' -> 'Trainable_Dataset/validation/mild/mild (624).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (518).jpg' -> 'Trainable_Dataset/validation/mild/mild (518).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (535).jpg' -> 'Trainable_Dataset/validation/mild/mild (535).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (519).jpg' -> 'Trainable_Dataset/validation/mild/mild (519).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (649).jpg' -> 'Trainable_Dataset/validation/mild/mild (649).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (666).jpg' -> 'Trainable_Dataset/validation/mild/mild (666).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (656).jpg' -> 'Trainable_Dataset/validation/mild/mild (656).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (596).jpg' -> 'Trainable_Dataset/validation/mild/mild (596).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (727).jpg' -> 'Trainable_Dataset/validation/mild/mild (727).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (577).jpg' -> 'Trainable_Dataset/validation/mild/mild (577).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (629).jpg' -> 'Trainable_Dataset/validation/mild/mild (629).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (506).jpg' -> 'Trainable_Dataset/validation/mild/mild (506).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (647).jpg' -> 'Trainable_Dataset/validation/mild/mild (647).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (439).jpg' -> 'Trainable_Dataset/validation/mild/mild (439).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (571).jpg' -> 'Trainable_Dataset/validation/mild/mild (571).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (769).jpg' -> 'Trainable_Dataset/validation/mild/mild (769).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (512).jpg' -> 'Trainable_Dataset/validation/mild/mild (512).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (582).jpg' -> 'Trainable_Dataset/validation/mild/mild (582).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (708).jpg' -> 'Trainable_Dataset/validation/mild/mild (708).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (604).jpg' -> 'Trainable_Dataset/validation/mild/mild (604).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (672).jpg' -> 'Trainable_Dataset/validation/mild/mild (672).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (530).jpg' -> 'Trainable_Dataset/validation/mild/mild (530).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (607).jpg' -> 'Trainable_Dataset/validation/mild/mild (607).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (694).jpg' -> 'Trainable_Dataset/validation/mild/mild (694).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (396).jpg' -> 'Trainable_Dataset/validation/mild/mild (396).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (673).jpg' -> 'Trainable_Dataset/validation/mild/mild (673).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (536).jpg' -> 'Trainable_Dataset/validation/mild/mild (536).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (469).jpg' -> 'Trainable_Dataset/validation/mild/mild (469).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (787).jpg' -> 'Trainable_Dataset/validation/mild/mild (787).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (684).jpg' -> 'Trainable_Dataset/validation/mild/mild (684).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (674).jpg' -> 'Trainable_Dataset/validation/mild/mild (674).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (488).jpg' -> 'Trainable_Dataset/validation/mild/mild (488).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (706).jpg' -> 'Trainable_Dataset/validation/mild/mild (706).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (667).jpg' -> 'Trainable_Dataset/validation/mild/mild (667).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (573).jpg' -> 'Trainable_Dataset/validation/mild/mild (573).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (441).jpg' -> 'Trainable_Dataset/validation/mild/mild (441).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (735).jpg' -> 'Trainable_Dataset/validation/mild/mild (735).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (458).jpg' -> 'Trainable_Dataset/validation/mild/mild (458).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/mild/mild (608).jpg' -> 'Trainable_Dataset/validation/mild/mild (608).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate' -> 'Trainable_Dataset/validation/moderate'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (490).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (490).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1018).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1018).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (659).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (659).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (492).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (492).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (746).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (746).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (938).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (938).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (602).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (602).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (635).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (635).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (537).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (537).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1032).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1032).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (832).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (832).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (682).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (682).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (909).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (909).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1011).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1011).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (628).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (628).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (798).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (798).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (485).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (485).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (452).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (452).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (981).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (981).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (945).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (945).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1043).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1043).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (424).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (424).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (908).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (908).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (549).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (549).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (845).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (845).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (676).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (676).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (433).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (433).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (787).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (787).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (885).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (885).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1101).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1101).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (518).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (518).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (854).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (854).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (833).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (833).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (644).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (644).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (538).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (538).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (990).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (990).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (437).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (437).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (671).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (671).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1094).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1094).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (670).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (670).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (482).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (482).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (512).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (512).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (782).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (782).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (603).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (603).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1086).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1086).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (998).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (998).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (880).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (880).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (708).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (708).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1067).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1067).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (465).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (465).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (593).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (593).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (667).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (667).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (663).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (663).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (567).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (567).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (596).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (596).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (488).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (488).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (943).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (943).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (608).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (608).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (622).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (622).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (931).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (931).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (431).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (431).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (638).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (638).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (547).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (547).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/validation/moderate/moderate (1048).jpg' -> 'Trainable_Dataset/validation/moderate/moderate (1048).jpg'
# ...
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (435).jpg' -> 'Trainable_Dataset/train/severe/severe (435).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (499).jpg' -> 'Trainable_Dataset/train/severe/severe (499).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (281).jpg' -> 'Trainable_Dataset/train/severe/severe (281).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (422).jpg' -> 'Trainable_Dataset/train/severe/severe (422).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (416).jpg' -> 'Trainable_Dataset/train/severe/severe (416).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (441).jpg' -> 'Trainable_Dataset/train/severe/severe (441).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (348).jpg' -> 'Trainable_Dataset/train/severe/severe (348).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (218).jpg' -> 'Trainable_Dataset/train/severe/severe (218).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (287).jpg' -> 'Trainable_Dataset/train/severe/severe (287).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (467).jpg' -> 'Trainable_Dataset/train/severe/severe (467).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (388).jpg' -> 'Trainable_Dataset/train/severe/severe (388).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (358).jpg' -> 'Trainable_Dataset/train/severe/severe (358).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (170).jpg' -> 'Trainable_Dataset/train/severe/severe (170).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (460).jpg' -> 'Trainable_Dataset/train/severe/severe (460).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (196).jpg' -> 'Trainable_Dataset/train/severe/severe (196).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (497).jpg' -> 'Trainable_Dataset/train/severe/severe (497).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (377).jpg' -> 'Trainable_Dataset/train/severe/severe (377).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe
jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (341).jpg' -> 'Trainable_Dataset/train/severe/severe (341).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (318).jpg' -> 'Trainable_Dataset/train/severe/severe (318).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (227).jpg' -> 'Trainable_Dataset/train/severe/severe (227).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (161).jpg' -> 'Trainable_Dataset/train/severe/severe (161).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (426).jpg' -> 'Trainable_Dataset/train/severe/severe (426).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (395).jpg' -> 'Trainable_Dataset/train/severe/severe (395).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (359).jpg' -> 'Trainable_Dataset/train/severe/severe (359).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (365).jpg' -> 'Trainable_Dataset/train/severe/severe (365).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (217).jpg' -> 'Trainable_Dataset/train/severe/severe (217).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (316).jpg' -> 'Trainable_Dataset/train/severe/severe (316).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (480).jpg' -> 'Trainable_Dataset/train/severe/severe (480).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (288).jpg' -> 'Trainable_Dataset/train/severe/severe (288).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (250).jpg' -> 'Trainable_Dataset/train/severe/severe (250).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (198).jpg' -> 'Trainable_Dataset/train/severe/severe (198).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (244).jpg' -> 'Trainable_Dataset/train/severe/severe (244).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (458).jpg' -> 'Trainable_Dataset/train/severe/severe (458).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (327).jpg' -> 'Trainable_Dataset/train/severe/severe (327).jpg'
# '/content/drive/MyDrive/Final_Year/Implementation/Gingivititis_level_prediction/Dataset/Trainable_dataset/train/severe/severe (370).jpg' -> 'Trainable_Dataset/train/severe/severe (370).jpg'

# %% [markdown]
# Set file paths

# %%
train_path      = '/content/Trainable_Dataset/train'
test_path       = '/content/Trainable_Dataset/test'
validation_path = '/content/Trainable_Dataset/test'
Save_model_path = '/content/drive/MyDrive/Final_year/Implementation/Machine_learning/Gingivititis_level_prediction/Weight'

# %% [markdown]
# Import libraries

# %%
import os
import cv2
import time
import shutil
import numpy as np
import pandas as pd
import matplotlib.image as mpimg

from glob import glob
from pathlib import Path
from matplotlib import pyplot as plt
from PIL import ImageFile, Image, ImageDraw

# %% [markdown]
# Import tensorflow and keras related libraries

# %%
import tensorflow as tf

from keras import backend as K
from keras.preprocessing import image
from keras.layers import Layer, InputSpec
from keras.layers import concatenate, Dense, Conv2D, MaxPooling2D, Flatten, Input, Activation, add, AveragePooling2D, BatchNormalization, Dropout

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %% [markdown]
# Import scikit-learn libraries for metrics and data preprocessing

# %%
from sklearn import metrics
from sklearn.manifold import TSNE
from sklearn.preprocessing import label_binarize
from mlxtend.plotting import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, roc_auc_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

# %% [markdown]
# Other config

# %%
# Display matplotlib plots inline
# %matplotlib inline

# Check for truncated images
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# ## Dataset visualization

# %% [markdown]
# View files count

# %%
no_of_train_files = sum([len(files) for i, j, files in os.walk(train_path)])
print(f"No of train files : {no_of_train_files}")
# Out:
# No of train files : 1850

# %%
no_of_train_files = sum([len(files) for i, j, files in os.walk(test_path)])
print(f"No of test files : {no_of_train_files}")
# Out:
# No of test files : 230

# %% [markdown]
# View folder content

# %%
train_dir = Path(train_path)
train_filepaths = list(train_dir.glob(r'**/*.jpg'))

test_dir = Path(test_path)
test_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
def path_to_image(filepath):
    labels = [str(filepath[i]).split("/")[-2] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop = True)

    return df

train_df = path_to_image(train_filepaths)
test_df = path_to_image(test_filepaths)

# %%
train_df.head(100)
# Out:
#                                              Filepath     Label
# 0   /content/Trainable_Dataset/train/healthy/healt...   healthy
# 1   /content/Trainable_Dataset/train/moderate/mode...  moderate
# 2   /content/Trainable_Dataset/train/moderate/mode...  moderate
# 3   /content/Trainable_Dataset/train/mild/mild (49...      mild
# 4   /content/Trainable_Dataset/train/mild/mild (40...      mild
# ..                                                ...       ...
# 95  /content/Trainable_Dataset/train/healthy/healt...   healthy
# 96  /content/Trainable_Dataset/train/healthy/healt...   healthy
# 97  /content/Trainable_Dataset/train/moderate/mode...  moderate
# 98  /content/Trainable_Dataset/train/moderate/mode...  moderate
# 99  /content/Trainable_Dataset/train/healthy/healt...   healthy
#
# [100 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Label').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
test_df.head(100)
# Out:
#                                              Filepath     Label
# 0   /content/Trainable_Dataset/test/moderate/moder...  moderate
# 1   /content/Trainable_Dataset/test/moderate/moder...  moderate
# 2   /content/Trainable_Dataset/test/moderate/moder...  moderate
# 3   /content/Trainable_Dataset/test/severe/severe ...    severe
# 4   /content/Trainable_Dataset/test/severe/severe ...    severe
# ..                                                ...       ...
# 95  /content/Trainable_Dataset/test/healthy/health...   healthy
# 96  /content/Trainable_Dataset/test/healthy/health...   healthy
# 97  /content/Trainable_Dataset/test/mild/mild (734...      mild
# 98  /content/Trainable_Dataset/test/healthy/health...   healthy
# 99  /content/Trainable_Dataset/test/healthy/health...   healthy
#
# [100 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Label').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Display some pictures of the dataset

# %%
# Create a DataFrame with one Label of each category
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %% [markdown]
# ## Dataset preparation

# %% [markdown]
# Create Categorie list

# %%
category = os.listdir(train_path)
category
print(f"Categories : {category}")
# Out:
# Categories : ['severe', 'healthy', 'moderate', 'mild']

# %% [markdown]
# Define data generator

# %%
data_gen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 360,
                                   height_shift_range = 0.1,
                                   shear_range = 0.1,
                                   zoom_range = 0.1,
                                   fill_mode='nearest',
                                   brightness_range = [0.9, 1.2],
                                   vertical_flip=True,
                                   horizontal_flip = True,
                                   validation_split=0.2
                                  )

# %% [markdown]
# Create batches

# %%
IMG_SIZE = 299
BATCH_SIZE = 16

# %%
print("\nTrain Batches: ")
train_generator = data_gen.flow_from_directory(
                                            directory=train_path,
                                            target_size=(IMG_SIZE,IMG_SIZE),
                                            batch_size=BATCH_SIZE,
                                            color_mode="rgb",
                                            class_mode="categorical",
                                            shuffle=True,
                                            subset='training')

print("\nValidation Batches: ")
valid_generator = data_gen.flow_from_directory(
                                            directory=train_path,
                                            target_size=(IMG_SIZE,IMG_SIZE),
                                            batch_size=BATCH_SIZE,
                                            color_mode="rgb",
                                            class_mode="categorical",
                                            shuffle=True,
                                            subset='validation')
# Out:
# Train Batches:
# Found 1482 images belonging to 4 classes.
#
# Validation Batches:
# Found 368 images belonging to 4 classes.

# %% [markdown]
# ## Model preparation

# %% [markdown]
# Download model

# %%
irv2 = tf.keras.applications.InceptionResNetV2(
    include_top=True,
    weights="imagenet",
    input_tensor=None,
    input_shape=None,
    pooling=None,
    classifier_activation="softmax",)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels.h5
# 225209952/225209952 [==============================] - 2s 0us/step

# %% [markdown]
# CNN Layer modifications

# %%
conv = irv2.layers[-20].output
conv  = Activation('relu')(conv)
conv = Dropout(0.5)(conv)
output = Flatten()(conv)
output = Dense(len(category), activation='softmax')(output)
conv_model = Model(inputs=irv2.input, outputs=output)

# %% [markdown]
# Model traning config

# %%
opt1=tf.keras.optimizers.Adam(
    learning_rate=0.01,
    epsilon=0.1)

conv_model.compile(optimizer=opt1,
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

# %% [markdown]
# Summary

# %%
conv_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 149, 149, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 149, 149, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 149, 149, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 147, 147, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 147, 147, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 147, 147, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 147, 147, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 147, 147, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 73, 73, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 73, 73, 80)           240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 73, 73, 80)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 71, 71, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 71, 71, 192)          576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 71, 71, 192)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 35, 35, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 35, 35, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 35, 35, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 35, 35, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 35, 35, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 35, 35, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 35, 35, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 35, 35, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 35, 35, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 35, 35, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 35, 35, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 35, 35, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 35, 35, 96)           288       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 35, 35, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 35, 35, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 35, 35, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 35, 35, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_15 (Ba  (None, 35, 35, 32)           96        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 35, 35, 32)           96        ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 35, 35, 48)           144       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_12 (Ba  (None, 35, 35, 32)           96        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 35, 35, 32)           96        ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 35, 35, 64)           192       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (Ba  (None, 35, 35, 32)           96        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_19 (Ba  (None, 35, 35, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 35, 35, 48)           144       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_18 (Ba  (None, 35, 35, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 35, 35, 32)           96        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 35, 35, 64)           192       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (Ba  (None, 35, 35, 32)           96        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_25 (Ba  (None, 35, 35, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 35, 35, 48)           144       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_24 (Ba  (None, 35, 35, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 35, 35, 32)           96        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 35, 35, 64)           192       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (Ba  (None, 35, 35, 32)           96        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_31 (Ba  (None, 35, 35, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 35, 35, 48)           144       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_30 (Ba  (None, 35, 35, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 35, 35, 32)           96        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 35, 35, 64)           192       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (Ba  (None, 35, 35, 32)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_37 (Ba  (None, 35, 35, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 35, 35, 48)           144       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_36 (Ba  (None, 35, 35, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 35, 35, 32)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 35, 35, 64)           192       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (Ba  (None, 35, 35, 32)           96        ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_43 (Ba  (None, 35, 35, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 35, 35, 48)           144       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 35, 35, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 35, 35, 32)           96        ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 35, 35, 64)           192       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (Ba  (None, 35, 35, 32)           96        ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_49 (Ba  (None, 35, 35, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 35, 35, 48)           144       ['conv2d_52[0][0]']
# ...
#
#  activation_183 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_183[0][0
#  )                                                                  ]']
#
#  activation_186 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  block8_6_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_183[0][0]',
#  e)                                                                  'activation_186[0][0]']
#
#  block8_6_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_6_mixed[0][0]']
#
#  custom_scale_layer_35 (Cus  (None, 8, 8, 2080)           0         ['block8_5_ac[0][0]',
#  tomScaleLayer)                                                      'block8_6_conv[0][0]']
#
#  block8_6_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_35[0][0]'
#                                                                     ]
#
#  conv2d_188 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_6_ac[0][0]']
#
#  batch_normalization_188 (B  (None, 8, 8, 192)            576       ['conv2d_188[0][0]']
#  atchNormalization)
#
#  activation_188 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  conv2d_189 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_188[0][0]']
#
#  batch_normalization_189 (B  (None, 8, 8, 224)            672       ['conv2d_189[0][0]']
#  atchNormalization)
#
#  activation_189 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_189[0][0
#  )                                                                  ]']
#
#  conv2d_187 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_6_ac[0][0]']
#
#  conv2d_190 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_189[0][0]']
#
#  batch_normalization_187 (B  (None, 8, 8, 192)            576       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  batch_normalization_190 (B  (None, 8, 8, 256)            768       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_187 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  activation_190 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (Cus  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  tomScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_36[0][0]'
#                                                                     ]
#
#  conv2d_192 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (B  (None, 8, 8, 192)            576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_193 (B  (None, 8, 8, 224)            672       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_194 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_191 (B  (None, 8, 8, 192)            576       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  batch_normalization_194 (B  (None, 8, 8, 256)            768       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 8, 8, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_197 (B  (None, 8, 8, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_195 (B  (None, 8, 8, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 8, 8, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 8, 8, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  activation_203 (Activation  (None, 8, 8, 192)            0         ['conv2d_200[0][0]']
#  )
#
#  dropout (Dropout)           (None, 8, 8, 192)            0         ['activation_203[0][0]']
#
#  flatten (Flatten)           (None, 12288)                0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 4)                    49156     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 49549476 (189.02 MB)
# Trainable params: 49493732 (188.80 MB)
# Non-trainable params: 55744 (217.75 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training InceptionResNetV2 model using Keras

# %%
#start = time.time()

#history = conv_model.fit(
                    #train_generator,
                    #steps_per_epoch=STEP_SIZE_TRAIN,
                    #validation_data=valid_generator,
                    #validation_steps=STEP_SIZE_VALID,
                    #epochs=100,
                    #verbose=1)

#print()
#print('===================================================================================================================')
#print("Total time: ", time.time() - start, "seconds")
# Out:
# Epoch 1/100
# 92/92 [==============================] - 194s 832ms/step - loss: 1.3461 - accuracy: 0.3383 - val_loss: 1.3388 - val_accuracy: 0.3696
100
# 92/92 [==============================] - 67s 723ms/step - loss: 0.0664 - accuracy: 0.9734 - val_loss: 3.3768 - val_accuracy: 0.4266
# Epoch 92/100
# 92/92 [==============================] - 67s 719ms/step - loss: 0.0700 - accuracy: 0.9734 - val_loss: 3.5974 - val_accuracy: 0.4130
# Epoch 93/100
# 92/92 [==============================] - 66s 715ms/step - loss: 0.0733 - accuracy: 0.9700 - val_loss: 3.7119 - val_accuracy: 0.3940
# Epoch 94/100
# 92/92 [==============================] - 67s 730ms/step - loss: 0.0800 - accuracy: 0.9686 - val_loss: 3.1358 - val_accuracy: 0.4103
# Epoch 95/100
# 92/92 [==============================] - 67s 723ms/step - loss: 0.0824 - accuracy: 0.9707 - val_loss: 3.3191 - val_accuracy: 0.4185
# Epoch 96/100
# 92/92 [==============================] - 67s 726ms/step - loss: 0.0761 - accuracy: 0.9700 - val_loss: 3.3782 - val_accuracy: 0.4321
# Epoch 97/100
# 92/92 [==============================] - 67s 726ms/step - loss: 0.0608 - accuracy: 0.9789 - val_loss: 3.5846 - val_accuracy: 0.4049
# Epoch 98/100
# 92/92 [==============================] - 67s 727ms/step - loss: 0.0727 - accuracy: 0.9782 - val_loss: 4.2375 - val_accuracy: 0.3261
# Epoch 99/100
# 92/92 [==============================] - 67s 728ms/step - loss: 0.0768 - accuracy: 0.9638 - val_loss: 3.6199 - val_accuracy: 0.4348
# Epoch 100/100
# 92/92 [==============================] - 67s 729ms/step - loss: 0.0600 - accuracy: 0.9775 - val_loss: 3.8256 - val_accuracy: 0.4538
#
# ===================================================================================================================
# Total time:  7562.797585487366 seconds

# %% [markdown]
# ## Plotting Accuracy of Gingivititis Classification Model

# %%
plt.title('Gingivititis Classification Accuracy Plot')
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train accuracy','Val accuracy'], loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-366c02f284a8> in <cell line: 2>()
#       1 plt.title('Gingivititis Classification Accuracy Plot')
# ----> 2 plt.plot(history.history['accuracy'])
#       3 plt.plot(history.history['val_accuracy'])
#       4 plt.ylabel('Accuracy')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %% [markdown]
# ## Gingivititis Classification Loss Plot

# %%
plt.title('Gingivititis Classification Loss Plot')
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train loss','Val loss'], loc='best')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6770cd3b332f> in <cell line: 2>()
#       1 plt.title('Gingivititis Classification Loss Plot')
# ----> 2 plt.plot(history.history['loss'])
#       3 plt.plot(history.history['val_loss'])
#       4 plt.ylabel('Loss')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'history' is not defined

# %% [markdown]
# ## Classification Report

# %%
print("Validation Batches")
vali_datagen = ImageDataGenerator( rescale = 1.0/255.)
vali_batches = vali_datagen.flow_from_directory(validation_path,
                                           target_size=(IMG_SIZE,IMG_SIZE),
                                           batch_size=BATCH_SIZE,
                                           color_mode="rgb",
                                           class_mode="categorical",
                                           shuffle=False)
# Out:
# Validation Batches
# Found 230 images belonging to 4 classes.

# %%
predictions = conv_model.predict(vali_batches,verbose=0)

y_pred = np.argmax(predictions, axis=1)
y_true = vali_batches.classes
y_prob = predictions
y_test = to_categorical(y_true)

report = classification_report(y_true, y_pred, target_names=category)

print("\nClassification Report:")
print(report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8eac059c8625> in <cell line: 1>()
# ----> 1 predictions = conv_model.predict(vali_batches,verbose=0)
#       2
#       3 y_pred = np.argmax(predictions, axis=1)
#       4 y_true = vali_batches.classes
#       5 y_prob = predictions
#
# NameError: name 'vali_batches' is not defined

# %% [markdown]
# ## Hyperparameter optimization

# %%
IMG_SIZE = 299
BATCH_SIZE = 16
EPOCHS = 100

# %%
data_gen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 360,
                                   height_shift_range = 0.1,
                                   shear_range = 0.1,
                                   zoom_range = 0.1,
                                   fill_mode='nearest',
                                   brightness_range = [0.9, 1.2],
                                   vertical_flip=True,
                                   horizontal_flip = True,
                                   validation_split=0.2
                                  )

# %%
print("\nTrain Batches: ")
train_generator = data_gen.flow_from_directory(
                                            directory=train_path,
                                            target_size=(IMG_SIZE,IMG_SIZE),
                                            batch_size=BATCH_SIZE,
                                            color_mode="rgb",
                                            class_mode="categorical",
                                            shuffle=True,
                                            subset='training')

print("\nValidation Batches: ")
valid_generator = data_gen.flow_from_directory(
                                            directory=train_path,
                                            target_size=(IMG_SIZE,IMG_SIZE),
                                            batch_size=BATCH_SIZE,
                                            color_mode="rgb",
                                            class_mode="categorical",
                                            shuffle=True,
                                            subset='validation')
# Out:
# Train Batches:
# Found 1665 images belonging to 4 classes.
#
# Validation Batches:
# Found 415 images belonging to 4 classes.

# %%
start = time.time()

# history = conv_model.fit(
#                     train_generator,
#                     steps_per_epoch=STEP_SIZE_TRAIN,
#                     validation_data=valid_generator,
#                     validation_steps=STEP_SIZE_VALID,
#                     epochs=EPOCHS,
#                     verbose=1)

print()
print('===================================================================================================================')
print("Total time: ", time.time() - start, "seconds")
# Out:
# ===================================================================================================================
# Total time:  0.00020241737365722656 seconds

# %%
predictions = conv_model.predict(vali_batches,verbose=0)

y_pred = np.argmax(predictions, axis=1)
y_true = vali_batches.classes
y_prob=predictions
y_test = to_categorical(y_true)

report = classification_report(y_true, y_pred, target_names=category)

print("\nClassification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#      healthy       0.94      0.95      0.95        85
#       severe       0.83      0.81      0.82        43
#     moderate       0.88      0.85      0.87        68
#         mild       0.86      0.91      0.89        34
#
#     accuracy                           0.89       230
#    macro avg       0.88      0.88      0.88       230
# weighted avg       0.89      0.89      0.89       230

# %% [markdown]
# ## Confusion matrix

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(category))
    plt.xticks(tick_marks, category, rotation=45)
    plt.yticks(tick_marks, category)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    #for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    for i in range (cm.shape[0]):
        for j in range (cm.shape[1]):
            plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Compute confusion matrix
cnf_matrix = confusion_matrix(y_true, y_pred)
np.set_printoptions(precision=2)

# %% [markdown]
# Confusion matrix, without normalization

# %%
# Plot non-normalized confusion matrix
plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=category, title='Confusion matrix, without normalization')
display()

# %% [markdown]
# Normalized confusion matrix

# %%
plt.figure(figsize=(10, 10))
plot_confusion_matrix(cnf_matrix, classes=category, normalize=True, title='Normalized confusion matrix')
display()

# %% [markdown]
# ## Receiver operating characteristic - ROC curve

# %%
fpr = {}
tpr = {}
roc_auc = dict()
for i in range(4):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_prob[:, i], drop_intermediate=False)
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
plt.plot(fpr[0], tpr[0],'v-',label=f'{category[0]}: ROC curve of (area = {"{:.2f}".format(roc_auc[0])})')
plt.plot(fpr[0], tpr[0],'c',label=f'{category[1]} : ROC curve of (area = {"{:.2f}".format(roc_auc[1])})')
plt.plot(fpr[0], tpr[0],'b',label=f'{category[2]} : ROC curve of (area = {"{:.2f}".format(roc_auc[2])})')
plt.plot(fpr[0], tpr[0],'g',label=f'{category[3]} : ROC curve of (area = {"{:.2f}".format(roc_auc[3])})')


plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of %s'%category[i])
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## 2D Tsne Visualization

# %%
tsne = TSNE(n_components=2, perplexity=10, learning_rate=100, angle=0.2, verbose=2)
transform = tsne.fit_transform(predictions)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 230 samples in 0.001s...
# [t-SNE] Computed neighbors for 230 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 230 / 230
# [t-SNE] Mean sigma: 0.000001
# [t-SNE] Computed conditional probabilities in 0.021s
# [t-SNE] Iteration 50: error = 59.6280212, gradient norm = 0.3841290 (50 iterations in 0.231s)
# [t-SNE] Iteration 100: error = 54.1146698, gradient norm = 0.4125197 (50 iterations in 0.235s)
# [t-SNE] Iteration 150: error = 54.3313065, gradient norm = 0.3726096 (50 iterations in 0.804s)
# [t-SNE] Iteration 200: error = 53.5354385, gradient norm = 0.3884193 (50 iterations in 0.301s)
# [t-SNE] Iteration 250: error = 54.4383888, gradient norm = 0.3664317 (50 iterations in 0.224s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.438389
# [t-SNE] Iteration 300: error = 0.2388765, gradient norm = 0.0048262 (50 iterations in 0.448s)
# [t-SNE] Iteration 350: error = 0.1709238, gradient norm = 0.0037782 (50 iterations in 0.066s)
# [t-SNE] Iteration 400: error = 0.1509641, gradient norm = 0.0025118 (50 iterations in 0.046s)
# [t-SNE] Iteration 450: error = 0.1426499, gradient norm = 0.0018314 (50 iterations in 0.045s)
# [t-SNE] Iteration 500: error = 0.1378531, gradient norm = 0.0012797 (50 iterations in 0.045s)
# [t-SNE] Iteration 550: error = 0.1347716, gradient norm = 0.0012282 (50 iterations in 0.049s)
# [t-SNE] Iteration 600: error = 0.1327183, gradient norm = 0.0011740 (50 iterations in 0.044s)
# [t-SNE] Iteration 650: error = 0.1311528, gradient norm = 0.0008014 (50 iterations in 0.046s)
# [t-SNE] Iteration 700: error = 0.1299589, gradient norm = 0.0008052 (50 iterations in 0.045s)
# [t-SNE] Iteration 750: error = 0.1289145, gradient norm = 0.0006808 (50 iterations in 0.047s)
# [t-SNE] Iteration 800: error = 0.1280671, gradient norm = 0.0006213 (50 iterations in 0.048s)
# [t-SNE] Iteration 850: error = 0.1273606, gradient norm = 0.0005788 (50 iterations in 0.051s)
# [t-SNE] Iteration 900: error = 0.1267570, gradient norm = 0.0006007 (50 iterations in 0.043s)
# [t-SNE] Iteration 950: error = 0.1262280, gradient norm = 0.0005919 (50 iterations in 0.042s)
# [t-SNE] Iteration 1000: error = 0.1257434, gradient norm = 0.0005719 (50 iterations in 0.046s)
# [t-SNE] KL divergence after 1000 iterations: 0.125743

# %%
def scale_to_01_range(x):
    # compute the distribution range
    value_range = (np.max(x) - np.min(x))
    starts_from_zero = x - np.min(x)

    return starts_from_zero / value_range

tx = transform[:, 0]
ty = transform[:, 1]

tx = scale_to_01_range(tx)
ty = scale_to_01_range(ty)

# %%
width = 2500
height = 2500
max_dim = 200
save_to_png = True
te_filepath = test_df['Filepath'].tolist()

full_image = Image.new('RGBA', (width, height))
for img, x, y in zip(te_filepath, tx, ty):
    tile = Image.open(img)
    rs = max(1, tile.width/max_dim, tile.height/max_dim)
    tile = tile.resize((int(tile.width/rs), int(tile.height/rs)), Image.ANTIALIAS)
    full_image.paste(tile, (int((width-max_dim)*x), int((height-max_dim)*y)), mask=tile.convert('RGBA'))
plt.figure(figsize = (16,12))
plt.imshow(full_image)

# %% [markdown]
# ## Saving Model

# %%
conv_model.save_weights(f'{Save_model_path}/gingivititis_classification_weight_final.hdf5')
